# %%
from g474 import *
# Out:
# COM15: STMicroelectronics STLink Virtual COM Port (COM15) [USB VID:PID=0483:374B SER=066CFF3530454D3043032340 LOCATION=1-1:x.2]

# %%
RCC.AHB2ENR
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
#         <td></td>
# ...

# %%
 RCC.AHB2ENR.GPIOCEN = 1

# %%
RCC.AHB2ENR
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
#         <td></td>
# ...

# %%
RCC.APB2ENR
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
#         <td></td>
# ...

# %%
RCC.APB2ENR.TIM1EN = 1

# %%
RCC.APB2ENR
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
#         <td></td>
# ...

# %%
GPIOC.MODER
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
# ...

# %%
GPIOC.MODER = 0XFFFFFFEA

# %%
GPIOC.MODER
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
# ...

# %%
GPIOC.AFRL
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
# ...

# %%
GPIOC.AFRL = 0X00000222

# %%
GPIOC.AFRL
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
# ...

# %%
TIM1.CCMR1
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
#         <td></td>
# ...

# %%
TIM1.CCMR1 = 0X00006060

# %%
TIM1.CCMR1
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
#         <td></td>
# ...

# %%
TIM1.CCMR2 = 0X00000060

# %%
TIM1.CCMR2
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
#         <td></td>
# ...

# %%
TIM1.CCER
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
#         <td></td>
# ...

# %%
TIM1.CCER = 0X00000333

# %%
TIM1.CCER
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
#         <td></td>
# ...

# %%
TIM1.BDTR
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
#         <td></td>
# ...

# %%
TIM1.BDTR = 1<<15

# %%
TIM1.BDTR = 0X00008000#0x00008064

# %%
TIM1.BDTR
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
#         <td></td>
# ...

# %%
TIM1.PSC
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
#         <td>0</td>
# ...

# %%
TIM1.PSC = 0

# %%
TIM1.PSC
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
#         <td>0</td>
# ...

# %%
TIM1.ARR
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
# ...

# %%
TIM1.ARR = 99

# %%
TIM1.ARR
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
# ...

# %%
TIM1.CR1
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
#         <td>0</td>
# ...

# %%
TIM1.CR1 = 1

# %%
TIM1.CR1
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
#         <td>0</td>
# ...

# %%
TIM1.CCR1
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
#         <td>0</td>
# ...

# %%
TIM1.CCR1 = 50

# %%
TIM1.CCR1
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
#         <td>0</td>
# ...

# %%
TIM1.CCR1 = 100

# %%
TIM1.CCR1 = 10

# %%
TIM1.CCR2 = 50

# %%
TIM1.CR2
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
#         <td></td>
# ...

# %%
TIM1.CCR2 = 50

# %%
TIM1.CCR2
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
#         <td>0</td>
# ...

# %%
TIM1.CCR1 = 0

# %%
TIM1.CCR2 = 100

# %%
TIM1.CCR3 = 100

# %%
TIM1.CCR2 = 0

# %%
TIM1.CCR3 = 0

# %%
TIM1.CCR3
# Out:
# <style type="text/css">
#     table.register th {
#         font-weight: normal;
#         text-align: center !important;
#         padding: 2px;
#     }
#     table.register td {
#         text-align: center !important;
#         border: 1px solid;
#         word-wrap: break-word;
#         padding: 2px;
#     }
#     .jp-RenderedHTMLCommon tbody tr:nth-child(even) {
#         background: var(--jp-layout-color0);
#     }
#     .jp-RenderedHTMLCommon tbody tr:hover {
#         background: rgba(0, 0, 0, 0);
#     }
# </style>
# <table class="register" style="width:800px">
#     <tr>
#         <th>31</th>
#         <th>30</th>
#         <th>29</th>
#         <th>28</th>
#         <th>27</th>
#         <th>26</th>
#         <th>25</th>
#         <th>24</th>
#         <th>23</th>
#         <th>22</th>
#         <th>21</th>
#         <th>20</th>
#         <th>19</th>
#         <th>18</th>
#         <th>17</th>
#         <th>16</th>
#     </tr>
#     <tr>
#         <td>0</td>
# ...
